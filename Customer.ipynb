# %%
import pandas as pd

# %%
df = pd.read_csv('churn_umsl_file1_copy.csv')
df.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/h9/546yj5w550d16fjy1357h_fh0000gn/T/ipykernel_13658/2838525938.py in <module>
# ----> 1 df = pd.read_csv('churn_umsl_file1_copy.csv')
#       2 df.columns
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
customer_number = df.customer_number.unique()
len(customer_number)
# Out:
# 10239

# %% [markdown]
# # Splitting the table

# %%
for customer in customer_number:
    df1 = df[df.customer_number == customer]
    print('Saving Customer ' + str(customer))
    df1.to_csv('Customers/Customer' + str(customer) +'.csv', index=False)
# Out:
# Saving Customer 0
# Saving Customer 100041
# Saving Customer 100064
# Saving Customer 100233
# Saving Customer 100300
# Saving Customer 100344
# Saving Customer 100636
# Saving Customer 100786
# Saving Customer 100838
# Saving Customer 100856
# Saving Customer 101078
# Saving Customer 101409
# Saving Customer 101505
# Saving Customer 101530
# Saving Customer 101596
# Saving Customer 101689
# Saving Customer 101723
# Saving Customer 101808
# Saving Customer 101839
# Saving Customer 101903
# Saving Customer 102088
# Saving Customer 102117
# Saving Customer 102254
# Saving Customer 102282
# Saving Customer 102313
# Saving Customer 102338
# Saving Customer 102424
# Saving Customer 102462
# Saving Customer 102473
# Saving Customer 102782
# Saving Customer 102828
# Saving Customer 102921
# Saving Customer 103007
# Saving Customer 103110
# Saving Customer 103136
# Saving Customer 103157
# Saving Customer 103172
# Saving Customer 103233
# Saving Customer 103278
# Saving Customer 103369
# ...

# %%
import os

# %%
files_c = os.listdir('Customers/')

# %%
for file in files_c:
    if(file.endswith('.csv')):
        df2 = pd.read_csv('Customers/' + file)
# Out:
# 10239
