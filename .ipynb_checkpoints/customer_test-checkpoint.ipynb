# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv('Customers/Customer4330.csv')

# %%
df['new_yearMonth'] = pd.to_datetime(df['YearMonth'].astype(str), format='%Y%m')

# %%
df
# Out:
#     customer_number  Division Customer_Type  YearMonth  \
# 0              4330         3             B     201602
# 1              4330         3             B     201603
# 2              4330         3             B     201605
# 3              4330         3             B     201606
# 4              4330         3             B     201607
# 5              4330         3             B     201608
# 6              4330         3             B     201609
# 7              4330         3             B     201610
# 8              4330         3             B     201611
# 9              4330         3             B     201612
# 10             4330         3             B     201701
# 11             4330         3             B     201702
# 12             4330         3             B     201703
# 13             4330         3             B     201704
# 14             4330         3             B     201705
# 15             4330         3             B     201706
# ...

# %%
df['difference'] = df['new_yearMonth'].diff()
df['difference']
# Out:
# 0         NaT
# 1     29 days
# 2     61 days
# 3     31 days
# 4     30 days
# 5     31 days
# 6     31 days
# 7     30 days
# 8     31 days
# 9     30 days
# 10    31 days
# 11    31 days
# 12    28 days
# 13    31 days
# 14    30 days
# 15    31 days
# 16    30 days
# 17    31 days
# 18    31 days
# 19    30 days
# 20    31 days
# 21    30 days
# 22    31 days
# 23   120 days
# 24    61 days
# 25    62 days
# 26    30 days
# 27    31 days
# 28    30 days
# 29    31 days
# 30    31 days
# 31    28 days
# 32   122 days
# 33    31 days
# Name: difference, dtype: timedelta64[ns]

# %%
df
# Out:
#     customer_number  Division Customer_Type  YearMonth  \
# 0              4330         3             B     201602
# 1              4330         3             B     201603
# 2              4330         3             B     201605
# 3              4330         3             B     201606
# 4              4330         3             B     201607
# 5              4330         3             B     201608
# 6              4330         3             B     201609
# 7              4330         3             B     201610
# 8              4330         3             B     201611
# 9              4330         3             B     201612
# 10             4330         3             B     201701
# 11             4330         3             B     201702
# 12             4330         3             B     201703
# 13             4330         3             B     201704
# 14             4330         3             B     201705
# 15             4330         3             B     201706
# ...

# %%
df1 = df.drop(df['difference'].idxmax())

# %%
df1 = df1.drop(df1['difference'].idxmin())

# %%
average = df1['difference'].mean()
average
# Out:
# Timedelta('36 days 08:30:58.064516129')

# %%
date = datetime.datetime(2019, 12, 31)
date
# Out:
# datetime.datetime(2019, 12, 31, 0, 0)

# %%
gap = date - df['new_yearMonth'].max()
gap
# Out:
# Timedelta('152 days 00:00:00')

# %%
if gap > average:
    df['churn'] = '1'
else:
    df['churn'] = '0'

# %%
df
# Out:
#     customer_number  Division Customer_Type  YearMonth  \
# 0              4330         3             B     201602
# 1              4330         3             B     201603
# 2              4330         3             B     201605
# 3              4330         3             B     201606
# 4              4330         3             B     201607
# 5              4330         3             B     201608
# 6              4330         3             B     201609
# 7              4330         3             B     201610
# 8              4330         3             B     201611
# 9              4330         3             B     201612
# 10             4330         3             B     201701
# 11             4330         3             B     201702
# 12             4330         3             B     201703
# 13             4330         3             B     201704
# 14             4330         3             B     201705
# 15             4330         3             B     201706
# ...

# %%
LRmodel.coef_
# Out:
# array([[-1.45408339e-13]])

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
LRmodel = LinearRegression()
x = df[['new_yearMonth']]
y = df[['Monthly_Sum_Sales']]

# %%
LRmodel.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(df.new_yearMonth, df.Monthly_Sum_Sales)

# %%
LRmodel.coef_
# Out:
# array([[-3.93232871e-15]])
